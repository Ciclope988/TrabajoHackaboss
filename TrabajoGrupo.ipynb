# %%
import requests
import random
import json
import pandas as pd
from requests import post
import time

# %%
response = post('https://api.igdb.com/v4/age_ratings', **{'headers': {'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z', 'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},'data': 'fields rating, category,organization,rating_category;'})
data = response.json()
df_edad = pd.DataFrame(data)
df_edad

# %%
response = post('https://api.igdb.com/v4/age_rating_categories', **{'headers': {'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z', 'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},'data': 'fields rating, created_at,organization,updated_at;'})
data = response.json()
df_ratincategory = pd.DataFrame(data)
df_ratincategory

# %%
response = post('https://api.igdb.com/v4/age_rating_content_descriptions', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields category, description;'})
data = response.json()
df_descripcion_rating = pd.DataFrame(data)
df_descripcion_rating = df_descripcion_rating2.sort_values(by='id', ascending=True)
df_descripcion_rating

# %%
df_descripcion_rating.info()

# %%
response = post('https://api.igdb.com/v4/age_rating_content_descriptions_v2', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields description,organization;'})
data = response.json()
df_descripcion_rating2 = pd.DataFrame(data)
df_descripcion_rating2 = df_descripcion_rating2.sort_values(by='id', ascending=True)
df_descripcion_rating2

# %%
df_combinado = pd.concat([df_ratincategory,df_descripcion_rating, df_descripcion_rating2])
df_rating = df_combinado.drop_duplicates(keep='first').reset_index(drop=True)
df_rating = df_rating.drop(["created_at", "updated_at"], axis=1)
df_rating

# %%
response = post('https://api.igdb.com/v4/age_rating_organizations', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_organization = pd.DataFrame(data)
df_organization

# %%
response = post('https://api.igdb.com/v4/alternative_names', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields comment,game,name;'})
data = response.json()
df_alternative_name = pd.DataFrame(data)
df_alternative_name

# %%
response = post('https://api.igdb.com/v4/artworks', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields game,height,width;'})
data = response.json()
df_artworks = pd.DataFrame(data)
df_artworks

# %%
response = post('https://api.igdb.com/v4/characters', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields character_gender,character_species,country_name,created_at,games,gender,mug_shot,name,slug,species,updated_at,url;'})
data = response.json()
df_characters = pd.DataFrame(data)
df_characters

# %%
response = post('https://api.igdb.com/v4/character_genders', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_genders = pd.DataFrame(data)
df_genders

# %%
response = post("https://api.igdb.com/v4/character_mug_shots", **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields height,width;'})
data = response.json()
df_character_mug_shots = pd.DataFrame(data)
df_character_mug_shots

# %%
response = post('https://api.igdb.com/v4/character_species', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_character_species = pd.DataFrame(data)
df_character_species

# %%
response = post('https://api.igdb.com/v4/collections', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields as_child_relations,as_parent_relations,created_at,games,name,slug,type,updated_at,url;'})
data = response.json()
df_collections = pd.DataFrame(data)
df_collections

# %%
df_collections.info()

# %%
response = post('https://api.igdb.com/v4/collection_memberships', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields collection,created_at,game,type,updated_at;'})
data = response.json()
df_collections_memberships = pd.DataFrame(data)
df_collections_memberships

# %%
response = post('https://api.igdb.com/v4/collection_membership_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields allowed_collection_type,created_at,name,updated_at;'})
data = response.json()
df_collection_membership_types = pd.DataFrame(data)
df_collection_membership_types

# %%
response = post('https://api.igdb.com/v4/collection_relations', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields child_collection,created_at,parent_collection,type,updated_at;'})
data = response.json()
df_collection_relations = pd.DataFrame(data)
df_collection_relations

# %%
response = post('https://api.igdb.com/v4/collection_relation_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_collection_relation_types = pd.DataFrame(data)
df_collection_relation_types

# %%
response = post('https://api.igdb.com/v4/collection_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_collection_types = pd.DataFrame(data)
df_collection_types

# %%
response = post('https://api.igdb.com/v4/companies', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields change_date_category, change_date_format,changed_company_id,country,created_at,developed,name,parent,slug,start_date,start_date_category,updated_at;'})
data = response.json()
df_companies = pd.DataFrame(data)
df_companies

# %%
response = post('https://api.igdb.com/v4/company_statuses', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_companies_statuses = pd.DataFrame(data)
df_companies_statuses

# %%
response = post('https://api.igdb.com/v4/covers', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields game,game_localization,height,width;'})
data = response.json()
df_covers = pd.DataFrame(data)
df_covers

# %%
response = post('https://api.igdb.com/v4/events', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,games,name,slug,time_zone,updated_at;'})
data = response.json()
df_events = pd.DataFrame(data)
df_events

# %%
response = post('https://api.igdb.com/v4/event_networks', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,event,network_type,updated_at,url;'})
data = response.json()
df_events_network = pd.DataFrame(data)
df_events_network

# %%
response = post('https://api.igdb.com/v4/external_games', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields category,countries,created_at,external_game_source,game,media,name,platform,updated_at,year;'})
data = response.json()
df_external_games = pd.DataFrame(data)
df_external_games

# %%
response = post('https://api.igdb.com/v4/external_game_sources', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_external_games_sources = pd.DataFrame(data)
df_external_games_sources

# %%
response = post('https://api.igdb.com/v4/franchises', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,games,name,slug,updated_at,url;'})
data = response.json()
df_franchises = pd.DataFrame(data)
df_franchises

# %%
response = post('https://api.igdb.com/v4/games', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields aggregated_rating,aggregated_rating_count,alternative_names,external_games,first_release_date,franchises,game_localizations,game_modes,game_status,game_type,genres,hypes,involved_companies,keywords,language_supports,multiplayer_modes,name,platforms,player_perspectives,rating,rating_count,release_dates,remakes,remasters,screenshots,similar_games,slug,standalone_expansions,status,updated_at;'})
data = response.json()
df_games = pd.DataFrame(data)
df_games

# %%
df_games.info()

# %%
response = post('https://api.igdb.com/v4/game_engines', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields companies,created_at,description,logo,name,platforms,slug,updated_at;'})
data = response.json()
df_game_engines = pd.DataFrame(data)
df_game_engines

# %%
response = post('https://api.igdb.com/v4/game_localizations', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,game,name,region,updated_at;'})
data = response.json()
df_game_localizations = pd.DataFrame(data)
df_game_localizations

# %%
response = post('https://api.igdb.com/v4/game_modes', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,slug,updated_at,url;'})
data = response.json()
df_game_mode = pd.DataFrame(data)
df_game_mode

# %%
response = post('https://api.igdb.com/v4/game_release_formats', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,format,updated_at;'})
data = response.json()
df_game_release_formats = pd.DataFrame(data)
df_game_release_formats

# %%
response = post('https://api.igdb.com/v4/game_statuses', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,updated_at;'})
data = response.json()
df_game_statuses = pd.DataFrame(data)
df_game_statuses

# %%
response = post('https://api.igdb.com/v4/game_time_to_beats', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields completely,count,created_at,game_id,hastily,normally,updated_at;'})
data = response.json()
df_game_time_to_beats = pd.DataFrame(data)
df_game_time_to_beats

# %%
response = post('https://api.igdb.com/v4/game_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,type,updated_at;'})
data = response.json()
df_game_type = pd.DataFrame(data)
df_game_type

# %%
response = post('https://api.igdb.com/v4/game_versions', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,features,game,games,updated_at,url;'})
data = response.json()
df_game_versions = pd.DataFrame(data)
df_game_versions

# %%
response = post('https://api.igdb.com/v4/game_version_features', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields category,position,title,values;'})
data = response.json()
df_game_versions_features = pd.DataFrame(data)
df_game_versions_features

# %%
response = post('https://api.igdb.com/v4/game_version_feature_values', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields game,game_feature,included_feature,note;'})
data = response.json()
df_game_versions_features_values = pd.DataFrame(data)
df_game_versions_features_values

# %%
response = post('https://api.igdb.com/v4/genres', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,slug,updated_at,url;'})
data = response.json()
df_genres = pd.DataFrame(data)
df_genres

# %%
response = post('https://api.igdb.com/v4/keywords', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,slug,updated_at,url;'})
data = response.json()
df_keywords = pd.DataFrame(data)
df_keywords

# %%
response = post('https://api.igdb.com/v4/involved_companies', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields company,created_at,developer,game,porting,publisher,supporting,updated_at;'})
data = response.json()
df_involved_companies = pd.DataFrame(data)
df_involved_companies

# %%
response = post('https://api.igdb.com/v4/languages', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,locale,name,native_name,updated_at;'})
data = response.json()
df_languages = pd.DataFrame(data)
df_languages

# %%
response = post('https://api.igdb.com/v4/language_supports', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,game,language,language_support_type,updated_at;'})
data = response.json()
df_languages_supports = pd.DataFrame(data)
df_languages_supports

# %%
response = post('https://api.igdb.com/v4/language_support_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_languages_support_types = pd.DataFrame(data)
df_languages_support_types

# %%
response = post('https://api.igdb.com/v4/multiplayer_modes', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields campaigncoop,dropin,game,lancoop,offlinecoop,offlinecoopmax,offlinemax,onlinecoop,onlinecoopmax,onlinemax,platform,splitscreen,splitscreenonline;'})
data = response.json()
df_multiplayer_modes = pd.DataFrame(data)
df_multiplayer_modes

# %%
response = post('https://api.igdb.com/v4/network_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_network_types = pd.DataFrame(data)
df_network_types

# %%
response = post('https://api.igdb.com/v4/platforms', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields alternative_name,category,created_at,generation,name,platform_family,platform_type,slug,updated_at,versions;'})
data = response.json()
df_plataforms = pd.DataFrame(data)
df_plataforms

# %%
response = post('https://api.igdb.com/v4/platform_families', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields name,slug;'})
data = response.json()
df_plataforms_families = pd.DataFrame(data)
df_plataforms_families

# %%
response = post('https://api.igdb.com/v4/platform_types', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,name,updated_at;'})
data = response.json()
df_plataforms_families = pd.DataFrame(data)
df_plataforms_families

# %%
response = post('https://api.igdb.com/v4/platform_versions', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields name,platform_version_release_dates;'})
data = response.json()
df_plataforms_versions = pd.DataFrame(data)
df_plataforms_versions

# %%
response = post('https://api.igdb.com/v4/platform_version_companies', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields comment,company,developer,manufacturer;'})
data = response.json()
df_plataforms_version_companies = pd.DataFrame(data)
df_plataforms_version_companies

# %%
response = post('https://api.igdb.com/v4/platform_version_release_dates', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields category,created_at,date,date_format,human,m,platform_version,region,release_region,updated_at,y;'})
data = response.json()
df_plataforms_version_release_dates = pd.DataFrame(data)
df_plataforms_version_release_dates

# %%
response = post('https://api.igdb.com/v4/release_date_statuses', **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,description,name,updated_at;'})
data = response.json()
df_plataforms_version_release_dates_statuses = pd.DataFrame(data)
df_plataforms_version_release_dates_statuses

# %%
response = post("https://api.igdb.com/v4/release_date_statuses", **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,description,name,updated_at;'})
data = response.json()
df_release_date_stats = pd.DataFrame(data)
df_release_date_stats

# %%
all_data = []
offset = 0
limit = 500

while True:
    query = f"fields name, release_dates.date, release_dates.status; limit {limit}; offset {offset};"
    response = post("https://api.igdb.com/v4/release_date_statuses",
        headers={
            'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',
        'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',
        },
        data=query
    )
    batch = response.json()
    
    if not batch:  
        break
    
    all_data.extend(batch)
    offset += limit

    time.sleep(4)  

# Convertir a DataFrame
df = pd.DataFrame(all_data)

# %%
response = post("https://api.igdb.com/v4/release_date_statuses", **
                {'headers': 
                 {'Client-ID':'gynzwnbf94dprczgrd0uto6uoz131z', 
                  'Authorization':'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj'},
                 'data': 'fields created_at,description,name,updated_at;'})
data = response.json()
df_release_date_status = pd.DataFrame(data)
df_release_date_status

# %%
query = "fields *; limit 500;" 

response = post(
    "https://api.igdb.com/v4/games/",
    headers={
        'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',
        'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',
    },
    data=query
)

data = response.json()
df_1 = pd.DataFrame(data)
df_1

# %%
query2 = "fields name, release_dates.date, release_dates.status; limit 500; offset 500;"
response = post("https://api.igdb.com/v4/games/",
    headers={
        'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',
        'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',
    },
    data=query
)

data = response.json()
df_2 = pd.DataFrame(data)
df_2

# %%
query3 = "fields name, release_dates.date, release_dates.status; limit 500; offset 1000;"
response = post("https://api.igdb.com/v4/games/",
    headers={
        'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',
        'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',
    },
    data=query
)

data = response.json()
df_3 = pd.DataFrame(data)
df_3

# %% [markdown]
#  all_data = []  **CREAMOS LA LISTA EN QUE SE ALAMACENARAN LOS DATOS** <br>
#  offset = 0 **Empezamos desde 0 a hacer las peticiones (despues se van sumando gracias al bucle while**<br>
#  limit = 500 **Esto es la cantidad de datos que vamos a pedir por solicitud<br>**
#
#  while True:  **Bucle "mientras pase esto, hacer esto"<br>
#    query = f"""
#     fields age_ratings, aggregated_rating, aggregated_rating_count, alternative_names, artworks, bundles, category,
#     collection, collections, cover, created_at, expanded_games, expansions, external_games, first_release_date,
#     forks, franchise, franchises, game_engines, game_localizations, game_modes, game_status, game_type, genres,
#     hypes, involved_companies, keywords, language_supports, multiplayer_modes, name, parent_game, platforms,
#     player_perspectives, ports, rating, rating_count, release_dates, remakes, remasters, similar_games, slug,
#     standalone_expansions, status, total_rating, updated_at, version_parent, version_title;
#     limit {limit};
#     offset {offset};
#     """ **Armamos query con los datos solicitados**<br><br>
#
#    print(f"Realizando solicitud con offset {offset}...")  **Esto es para saber que sigue corriendo y seguimos sacando datos, ademas de en que cantidad de datos estamos**<br><br>
#
#    response = requests.post(  <br>
#         "https://api.igdb.com/v4/games/",  **Endpoint de la API**<br>
#         headers={<br>
#             'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',  **Cliente ID de IGDB**<br>
#            'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',  **Bearer Token de IGDB**<br>
#        }, **Metodo post porque la API asi nos los solicita, no nos deja hacer GET**<br>
#        data=query<br>
#     )<br><br>
#
#    if response.status_code == 200:  **Como queremos saber que va todo bien, necesitamos que nos diga si es un 200 o en caso contratio nos diga que codigo nos da de error**<br>
#         print(f"Respuesta recibida con éxito. Código de estado: {response.status_code}")<br>
#     else:<br>
#         print(f"Error en la solicitud. Código de estado: {response.status_code}")<br><br>
#
#    batch = response.json() **BATCH=LOTE** **Queremos que nuestros datos sean almacenados en un JSON, asi que le damos ese formato**<br><br>
#
#    if not batch:<br>
#         print("No hay más datos, terminando...")<br>
#         break  **Frenamos el bucle en caso de que ya conseguimos toda la informacion necesaria**<br><br>
#
#    all_data.extend(batch)<br>
#    offset += limit<br>
#    time.sleep(4)  **Pausa de 4 segundos entre solicitudes para que la API nos deje sacar los datos que necesitamos**
# <br><br>
#  print("Proceso terminado. Datos recopilados.") **Una vez finalizado, nos avisa que obtuvimos todo**<br>
#  df = pd.DataFrame(all_data) **convertimos a dataframe para poder trabajarlo con pandas** <br>
#  print(df.head()) **Vemos los primeros elementos del DF para poder empezar a sacar concluciones (luego hacemos el** .info() y .describe()<br><br>
#
#  **Para no tener que realizar la solicitud cada vez que queremos volver a conectarnos, almacenamos los datos en un archivo JSON, de esta manera no debeos esperar el tiempo entre la solicitud y la descargar de la misma**
#  df.to_json('C:/Users/aguja/Desktop/datos_juegos.json', orient='records', lines=True)
# print("Archivo guardado en 'C:/Users/aguja/Desktop/datos_juegos.json'") **Aqui pedimos que imprima que se guardó el archivo

# %%
import requests
import pandas as pd
import time

all_data = []
offset = 0
limit = 500

while True:
    query = f"""
    fields age_ratings, aggregated_rating, aggregated_rating_count, alternative_names, artworks, bundles, category,
    collection, collections, cover, created_at, expanded_games, expansions, external_games, first_release_date,
    forks, franchise, franchises, game_engines, game_localizations, game_modes, game_status, game_type, genres,
    hypes, involved_companies, keywords, language_supports, multiplayer_modes, name, parent_game, platforms,
    player_perspectives, ports, rating, rating_count, release_dates, remakes, remasters, similar_games, slug,
    standalone_expansions, status, total_rating, updated_at, version_parent, version_title;
    limit {limit};
    offset {offset};
    """

    print(f"Realizando solicitud con offset {offset}...")

    response = requests.post(
        "https://api.igdb.com/v4/games/",
        headers={
            'Client-ID': 'gynzwnbf94dprczgrd0uto6uoz131z',
            'Authorization': 'Bearer u2409t8r8i6vygc08ttuc0x4cetbyj',
        },
        data=query
    )

    if response.status_code == 200:
        print(f"Respuesta recibida con éxito. Código de estado: {response.status_code}")
    else:
        print(f"Error en la solicitud. Código de estado: {response.status_code}")
        break

    batch = response.json()

    if not batch:
        print("No hay más datos, terminando...")
        break

    all_data.extend(batch)
    offset += limit
    time.sleep(2)

print("Proceso terminado. Datos recopilados.")

df = pd.DataFrame(all_data)

df.to_json('C:/Users/aguja/Desktop/datos_juegos.json', orient='records', lines=True)
print("Archivo guardado en 'C:/Users/aguja/Desktop/datos_juegos.json'")
# Out:
# Realizando solicitud con offset 0...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 1000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 1500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 2000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 2500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 3000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 3500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 4000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 4500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 5000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 5500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 6000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 6500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 7000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 7500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 8000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 8500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 9000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 9500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 10000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 10500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 11000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 11500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 12000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 12500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 13000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 13500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 14000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 14500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 15000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 15500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 16000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 16500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 17000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 17500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 18000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 18500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 19000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 19500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 20000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 20500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 21000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 21500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 22000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 22500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 23000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 23500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 24000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 24500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 25000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 25500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 26000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 26500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 27000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 27500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 28000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 28500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 29000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 29500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 30000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 30500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 31000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 31500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 32000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 32500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 33000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 33500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 34000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 34500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 35000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 35500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 36000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 36500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 37000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 37500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 38000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 38500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 39000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 39500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 40000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 40500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 41000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 41500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 42000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 42500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 43000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 43500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 44000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 44500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 45000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 45500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 46000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 46500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 47000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 47500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 48000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 48500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 49000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 49500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 50000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 50500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 51000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 51500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 52000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 52500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 53000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 53500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 54000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 54500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 55000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 55500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 56000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 56500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 57000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 57500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 58000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 58500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 59000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 59500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 60000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 60500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 61000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 61500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 62000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 62500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 63000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 63500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 64000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 64500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 65000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 65500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 66000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 66500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 67000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 67500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 68000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 68500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 69000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 69500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 70000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 70500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 71000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 71500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 72000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 72500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 73000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 73500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 74000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 74500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 75000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 75500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 76000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 76500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 77000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 77500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 78000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 78500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 79000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 79500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 80000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 80500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 81000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 81500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 82000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 82500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 83000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 83500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 84000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 84500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 85000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 85500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 86000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 86500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 87000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 87500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 88000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 88500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 89000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 89500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 90000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 90500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 91000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 91500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 92000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 92500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 93000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 93500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 94000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 94500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 95000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 95500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 96000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 96500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 97000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 97500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 98000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 98500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 99000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 99500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 100000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 100500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 101000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 101500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 102000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 102500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 103000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 103500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 104000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 104500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 105000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 105500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 106000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 106500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 107000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 107500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 108000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 108500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 109000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 109500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 110000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 110500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 111000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 111500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 112000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 112500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 113000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 113500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 114000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 114500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 115000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 115500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 116000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 116500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 117000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 117500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 118000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 118500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 119000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 119500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 120000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 120500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 121000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 121500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 122000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 122500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 123000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 123500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 124000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 124500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 125000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 125500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 126000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 126500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 127000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 127500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 128000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 128500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 129000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 129500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 130000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 130500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 131000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 131500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 132000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 132500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 133000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 133500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 134000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 134500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 135000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 135500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 136000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 136500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 137000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 137500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 138000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 138500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 139000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 139500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 140000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 140500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 141000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 141500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 142000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 142500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 143000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 143500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 144000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 144500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 145000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 145500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 146000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 146500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 147000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 147500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 148000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 148500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 149000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 149500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 150000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 150500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 151000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 151500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 152000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 152500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 153000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 153500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 154000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 154500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 155000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 155500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 156000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 156500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 157000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 157500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 158000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 158500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 159000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 159500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 160000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 160500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 161000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 161500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 162000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 162500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 163000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 163500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 164000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 164500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 165000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 165500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 166000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 166500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 167000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 167500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 168000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 168500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 169000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 169500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 170000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 170500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 171000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 171500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 172000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 172500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 173000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 173500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 174000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 174500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 175000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 175500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 176000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 176500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 177000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 177500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 178000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 178500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 179000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 179500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 180000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 180500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 181000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 181500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 182000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 182500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 183000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 183500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 184000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 184500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 185000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 185500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 186000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 186500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 187000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 187500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 188000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 188500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 189000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 189500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 190000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 190500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 191000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 191500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 192000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 192500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 193000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 193500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 194000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 194500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 195000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 195500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 196000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 196500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 197000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 197500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 198000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 198500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 199000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 199500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 200000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 200500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 201000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 201500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 202000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 202500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 203000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 203500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 204000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 204500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 205000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 205500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 206000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 206500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 207000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 207500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 208000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 208500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 209000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 209500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 210000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 210500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 211000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 211500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 212000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 212500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 213000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 213500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 214000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 214500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 215000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 215500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 216000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 216500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 217000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 217500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 218000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 218500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 219000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 219500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 220000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 220500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 221000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 221500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 222000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 222500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 223000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 223500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 224000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 224500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 225000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 225500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 226000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 226500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 227000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 227500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 228000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 228500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 229000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 229500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 230000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 230500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 231000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 231500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 232000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 232500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 233000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 233500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 234000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 234500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 235000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 235500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 236000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 236500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 237000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 237500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 238000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 238500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 239000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 239500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 240000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 240500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 241000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 241500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 242000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 242500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 243000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 243500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 244000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 244500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 245000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 245500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 246000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 246500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 247000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 247500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 248000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 248500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 249000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 249500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 250000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 250500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 251000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 251500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 252000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 252500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 253000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 253500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 254000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 254500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 255000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 255500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 256000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 256500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 257000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 257500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 258000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 258500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 259000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 259500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 260000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 260500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 261000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 261500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 262000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 262500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 263000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 263500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 264000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 264500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 265000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 265500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 266000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 266500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 267000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 267500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 268000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 268500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 269000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 269500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 270000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 270500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 271000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 271500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 272000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 272500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 273000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 273500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 274000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 274500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 275000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 275500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 276000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 276500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 277000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 277500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 278000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 278500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 279000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 279500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 280000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 280500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 281000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 281500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 282000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 282500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 283000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 283500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 284000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 284500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 285000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 285500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 286000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 286500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 287000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 287500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 288000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 288500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 289000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 289500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 290000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 290500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 291000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 291500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 292000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 292500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 293000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 293500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 294000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 294500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 295000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 295500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 296000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 296500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 297000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 297500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 298000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 298500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 299000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 299500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 300000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 300500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 301000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 301500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 302000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 302500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 303000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 303500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 304000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 304500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 305000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 305500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 306000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 306500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 307000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 307500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 308000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 308500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 309000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 309500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 310000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 310500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 311000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 311500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 312000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 312500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 313000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 313500...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 314000...
# Respuesta recibida con éxito. Código de estado: 200
# Realizando solicitud con offset 314500...
# Respuesta recibida con éxito. Código de estado: 200
# No hay más datos, terminando...
# Proceso terminado. Datos recopilados.
# Archivo guardado en 'C:/Users/aguja/Desktop/datos_juegos.json'

# %%
df
# Out:
#             id  category     cover  created_at game_engines game_modes  \
# 0       330684        14  437074.0  1738949769        [439]  [1, 2, 4]
# 1       177310         0  256495.0  1634642434        [750]        [1]
# 2        43460         3   39875.0  1499154074          NaN        NaN
# 3       282079         5  354470.0  1704811215          NaN        [1]
# 4       338541         7  449138.0  1743773041          NaN        [1]
# ...        ...       ...       ...         ...          ...        ...
# 314166   89219         1   63646.0  1519569219          NaN  [1, 2, 3]
# 314167  154420         3  156717.0  1625225295          NaN        [1]
# 314168    8993         0   94202.0  1423389511        [578]        [1]
# 314169    6253         0  208920.0  1398039372         [31]        [1]
# 314170   11261         0   94667.0  1435219891        [254]        [1]
#
#                 genres     involved_companies  \
# 0             [10, 33]               [306710]
# 1             [13, 32]               [190784]
# 2                 [25]                    NaN
# 3               [5, 8]               [253727]
# 4                 [10]               [314234]
# ...                ...                    ...
# 314166        [13, 15]                [62563]
# 314167             [5]                    NaN
# 314168        [15, 32]                [96983]
# 314169  [2, 9, 31, 32]                [14897]
# 314170         [2, 31]  [24745, 53095, 53094]
#
#                                                  name  parent_game  ...  \
# 0                       Nightmare Kart: The Old Karts     295664.0  ...
# 1                                   The Undying Beast          NaN  ...
# 2                                   Sengoku Anthology          NaN  ...
# 3                            Rockman X: New Year 2023       1741.0  ...
# 4                     Mario Kart Tour: Vancouver Tour      85663.0  ...
# ...                                               ...          ...  ...
# 314166  Stronghold Crusader II: The Templar &The Duke      10929.0  ...
# 314167                                 Catacombs Pack          NaN  ...
# 314168                              Anomaly Defenders          NaN  ...
# 314169                        Time Gentlemen, Please!          NaN  ...
# 314170                               The Black Mirror          NaN  ...
#
#        status game_status ports franchise  remakes  remasters expansions  \
# 0         NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 1         NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 2         NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 3         NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 4         NaN         NaN   NaN       NaN      NaN        NaN        NaN
# ...       ...         ...   ...       ...      ...        ...        ...
# 314166    NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 314167    NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 314168    NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 314169    NaN         NaN   NaN       NaN      NaN        NaN        NaN
# 314170    NaN         NaN   NaN       NaN      NaN        NaN        NaN
#
#        expanded_games  standalone_expansions forks
# 0                 NaN                    NaN   NaN
# 1                 NaN                    NaN   NaN
# 2                 NaN                    NaN   NaN
# 3                 NaN                    NaN   NaN
# 4                 NaN                    NaN   NaN
# ...               ...                    ...   ...
# 314166            NaN                    NaN   NaN
# 314167            NaN                    NaN   NaN
# 314168            NaN                    NaN   NaN
# 314169            NaN                    NaN   NaN
# 314170            NaN                    NaN   NaN
#
# [314171 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314171 entries, 0 to 314170
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       314171 non-null  int64
#  1   category                 314171 non-null  int64
#  2   cover                    248326 non-null  float64
#  3   created_at               314171 non-null  int64
#  4   game_engines             39946 non-null   object
#  5   game_modes               191081 non-null  object
#  6   genres                   260224 non-null  object
#  7   involved_companies       146233 non-null  object
#  8   name                     314171 non-null  object
#  9   parent_game              43472 non-null   float64
#  10  platforms                242097 non-null  object
#  11  player_perspectives      119003 non-null  object
#  12  release_dates            240745 non-null  object
#  13  slug                     314171 non-null  object
#  14  updated_at               314171 non-null  int64
#  15  game_type                314171 non-null  int64
#  16  artworks                 135640 non-null  object
#  17  external_games           290518 non-null  object
#  18  first_release_date       225241 non-null  float64
#  19  similar_games            260118 non-null  object
#  20  age_ratings              69618 non-null   object
#  21  keywords                 110893 non-null  object
#  22  collections              42977 non-null   object
#  23  language_supports        172976 non-null  object
#  24  franchises               24679 non-null   object
#  25  rating                   31926 non-null   float64
#  26  rating_count             31926 non-null   float64
#  27  total_rating             37426 non-null   float64
#  28  alternative_names        70974 non-null   object
#  29  multiplayer_modes        15410 non-null   object
#  30  version_parent           7422 non-null    float64
#  31  version_title            7354 non-null    object
#  32  hypes                    15274 non-null   float64
#  33  game_localizations       28867 non-null   object
#  34  aggregated_rating        16133 non-null   float64
#  35  aggregated_rating_count  16133 non-null   float64
#  36  bundles                  15408 non-null   object
#  37  status                   21972 non-null   float64
#  38  game_status              21972 non-null   float64
#  39  ports                    4508 non-null    object
#  40  franchise                1355 non-null    float64
#  41  remakes                  1100 non-null    object
#  42  remasters                1124 non-null    object
#  43  expansions               787 non-null     object
#  44  expanded_games           1592 non-null    object
#  45  standalone_expansions    321 non-null     object
#  46  forks                    69 non-null      object
# dtypes: float64(13), int64(5), object(29)
# memory usage: 112.7+ MB

# %%
df.describe()
# Out:
#                   id       category          cover    created_at  \
# count  314171.000000  314171.000000  248326.000000  3.141710e+05
# mean   169949.438745       0.902378  257434.931284  1.607660e+09
# std     98390.839790       2.745687  125510.362172  9.416613e+07
# min         1.000000       0.000000     109.000000  1.297556e+09
# 25%     85420.500000       0.000000  155459.750000  1.517405e+09
# 50%    169463.000000       0.000000  265770.500000  1.631398e+09
# 75%    254686.500000       0.000000  366343.500000  1.687796e+09
# max    343448.000000      14.000000  457420.000000  1.747238e+09
#
#          parent_game    updated_at      game_type  first_release_date  \
# count   43472.000000  3.141710e+05  314171.000000        2.252410e+05
# mean    77815.885305  1.723509e+09       0.902378        1.417512e+09
# std     88409.186621  2.913817e+07       2.745687        3.384775e+08
# min         1.000000  1.441385e+09       0.000000       -6.943968e+08
# 25%      3512.000000  1.698751e+09       0.000000        1.277683e+09
# 50%     34894.000000  1.739945e+09       0.000000        1.540771e+09
# 75%    134432.000000  1.746364e+09       0.000000        1.667002e+09
# max    343396.000000  1.747269e+09      14.000000        1.923955e+09
#
#              rating  rating_count  total_rating  version_parent         hypes  \
# count  31926.000000  31926.000000  37426.000000     7422.000000  15274.000000
# mean      66.775367     26.967425     66.744070   107855.215845      4.029724
# std       14.142721    128.896795     14.600130    92094.568044     20.193029
# min       10.000000      0.000000      0.000000        4.000000      1.000000
# 25%       59.969779      0.000000     59.972318    17999.500000      1.000000
# 50%       70.000000      3.000000     70.000000   109545.500000      1.000000
# 75%       77.666796     12.000000     77.666667   163801.250000      2.000000
# max      100.000000   4959.000000    100.000000   342382.000000   1038.000000
#
#        aggregated_rating  aggregated_rating_count        status   game_status  \
# count       16133.000000             16133.000000  21972.000000  21972.000000
# mean           69.454628                 2.984442      4.572865      4.572865
# std            16.109957                 3.333730      1.762777      1.762777
# min             0.000000                 0.000000      0.000000      0.000000
# 25%            60.000000                 1.000000      4.000000      4.000000
# 50%            72.000000                 2.000000      4.000000      4.000000
# 75%            80.000000                 3.000000      5.000000      5.000000
# max           100.000000                52.000000      8.000000      8.000000
#
#          franchise
# count  1355.000000
# mean    125.007380
# std     119.759983
# min       1.000000
# 25%      24.000000
# 50%      84.000000
# 75%     220.000000
# max     442.000000

# %%
total_nans = df.isna().sum().sum()
print("Total de NaN en el DataFrame:", total_nans)
# Out:
# Total de NaN en el DataFrame: 9354000

# %%
class IGDBData:
    def __init__(self, data_path):
        self.df = pd.read_json(data_path, lines=True)
        
    def clean_data(self):
        self.df = self.df.dropna(subset=['rating'])
        
        return self
